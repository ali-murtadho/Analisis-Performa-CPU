# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
dtr = pd.read_excel("cpu_training.xlsx")
dtr
# Out:
#      MYCT  MMIN   MMAX  CACH  CHMIN  CHMAX  PERFORMANCE
# 0     125   256   6000   256     16    128          198
# 1      29  8000  32000    32      8     32          269
# 2      29  8000  32000    32      8     32          220
# 3      29  8000  32000    32      8     32          172
# 4      29  8000  16000    32      8     16          132
# ..    ...   ...    ...   ...    ...    ...          ...
# 179   160  1000   8000    16      1     14           60
# 180   160  2000   8000    32      1     13          109
# 181   240   512   1000     8      1      3            6
# 182   240   512   2000     8      1      5           11
# 183   105  2000   4000     8      3      8           22
#
# [184 rows x 7 columns]

# %%
dts = pd.read_excel("cpu_testing.xlsx")
dts
# Out:
#     MYCT  MMIN   MMAX  CACH  CHMIN  CHMAX  PERFORMANCE
# 0    105  2000   6000    16      6     16           33
# 1    105  2000   8000    16      4     14           58
# 2     52  4000  16000    32      4     12          130
# 3     70  4000  12000     8      6      8           75
# 4     59  4000  12000    32      6     12          113
# 5     59  8000  16000    64     12     24          188
# 6     26  8000  24000    32      8     16          173
# 7     26  8000  32000    64     12     16          248
# 8     26  8000  32000   128     24     32          405
# 9    116  2000   8000    32      5     28           70
# 10    50  2000  32000    24      6     26          114
# 11    50  2000  32000    48     26     52          208
# 12    50  2000  32000   112     52    104          307
# 13    50  4000  32000   112     52    104          397
# 14    30  8000  64000    96     12    176          915

# %%
ds = pd.read_excel("cpu.xls")
ds
# Out:
#      MYCT  MMIN   MMAX  CACH  CHMIN  CHMAX  PERFORMANCE
# 0     125   256   6000   256     16    128          198
# 1      29  8000  32000    32      8     32          269
# 2      29  8000  32000    32      8     32          220
# 3      29  8000  32000    32      8     32          172
# 4      29  8000  16000    32      8     16          132
# ..    ...   ...    ...   ...    ...    ...          ...
# 194    50  2000  32000    24      6     26          114
# 195    50  2000  32000    48     26     52          208
# 196    50  2000  32000   112     52    104          307
# 197    50  4000  32000   112     52    104          397
# 198    30  8000  64000    96     12    176          915
#
# [199 rows x 7 columns]

# %%
x = ds.iloc[:,0:6].values
y = ds['PERFORMANCE'].values

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.08)

# %%
print("Jumlah Data Training = ", xtrain.shape)
print("Jumlah Data Testing = ", xtest.shape)
# Out:
# Jumlah Data Training =  (183, 6)
# Jumlah Data Testing =  (16, 6)

# %%
import tensorflow as tf

# %%
model = tf.keras.models.Sequential()

# %%
model.add(tf.keras.layers.Dense(units=6, activation='relu'))
model.add(tf.keras.layers.Dense(units=9, activation='relu'))
model.add(tf.keras.layers.Dense(units=1))
model.compile(loss='mean_absolute_error', optimizer=tf.keras.optimizers.Adam(0.001))
model.fit(xtrain, ytrain, epochs=800, batch_size=128)
# Out:
# Epoch 1/800
# 2/2 [==============================] - 3s 7ms/step - loss: 283.3446
# Epoch 2/800
# 2/2 [==============================] - 0s 5ms/step - loss: 203.5650
# Epoch 3/800
# 2/2 [==============================] - 0s 8ms/step - loss: 133.8902
# Epoch 4/800
# 2/2 [==============================] - 0s 8ms/step - loss: 72.5735
# Epoch 5/800
# 2/2 [==============================] - 0s 10ms/step - loss: 44.6588
# Epoch 6/800
# 2/2 [==============================] - 0s 8ms/step - loss: 61.7739
# Epoch 7/800
# 2/2 [==============================] - 0s 7ms/step - loss: 80.6816
# Epoch 8/800
# 2/2 [==============================] - 0s 7ms/step - loss: 85.9947
# Epoch 9/800
# 2/2 [==============================] - 0s 10ms/step - loss: 83.1059
# Epoch 10/800
# 2/2 [==============================] - 0s 8ms/step - loss: 72.6783
# Epoch 11/800
# 2/2 [==============================] - 0s 5ms/step - loss: 56.3340
# Epoch 12/800
# ...

# %%
pred = model.predict(xtest)
pred
# Out:
# 1/1 [==============================] - 0s 90ms/step
# array([[133.62395  ],
#        [ 69.18169  ],
#        [ 22.553291 ],
#        [  7.1109076],
#        [ 18.589666 ],
#        [ 39.14968  ],
#        [ 56.89004  ],
#        [130.0551   ],
#        [119.30603  ],
#        [132.99438  ],
#        [ 18.291683 ],
#        [218.76959  ],
#        [ 69.18169  ],
#        [ 53.28472  ],
#        [ 32.39932  ],
#        [ 23.519133 ]], dtype=float32)

# %%
plt.plot(ytest, pred, 'b', "Hasil Prediksi")
plt.figure()

# %%
model.evaluate(xtest, ytest)
# Out:
# 1/1 [==============================] - 0s 495ms/step - loss: 15.7165
# 15.716490745544434

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(ytest, pred)
mae
# Out:
# 15.716492474079132

# %%
a = range(len(ytest))

plt.scatter(a,pred, color = 'blue')
plt.scatter(a,ytest, color='red')
plt.title("Hasil Prediksi")
plt.xlabel("Data Testing")
plt.ylabel("Data Aktual")
plt.show()
